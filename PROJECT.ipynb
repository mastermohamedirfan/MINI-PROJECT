# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
wine=pd.read_csv("C:\\Users\\aedpu\\Downloads\\winequality-red (1).csv")

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
newdataset=wine.drop(['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','sulphates','alcohol'],axis=1)

# %%
newdataset
# Out:
#         pH  quality
# 0     3.51        5
# 1     3.20        5
# 2     3.26        5
# 3     3.16        6
# 4     3.51        5
# ...    ...      ...
# 1594  3.45        5
# 1595  3.52        6
# 1596  3.42        6
# 1597  3.57        5
# 1598  3.39        6
#
# [1599 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
pt.scatter(x,y)
pt.xlabel('PH')
pt.ylabel('quality')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
X_train.shape
# Out:
# (1279, 1)

# %%
X_test.shape
# Out:
# (320, 1)

# %%
Y_train.shape
# Out:
# (1279, 1)

# %%
Y_test.shape
# Out:
# (320, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
X_train
# Out:
# array([[ 9.9],
#        [10.8],
#        [ 9.9],
#        ...,
#        [ 7.9],
#        [13. ],
#        [ 9.8]])

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(X_test)

# %%
y_predict
# Out:
# array([[3.1614224 ],
#        [3.32413282],
#        [3.26386971],
#        [3.19758028],
#        [3.07705404],
#        [3.31810651],
#        [3.25181708],
#        [3.25181708],
#        [3.28194864],
#        [3.38439594],
#        [3.29400127],
#        [3.23373815],
#        [3.24579077],
#        [3.51094849],
#        [3.48684325],
#        [3.3602907 ],
#        [3.31810651],
#        [3.24579077],
#        [3.43260644],
#        [3.36631701],
#        [3.38439594],
#        [3.26989602],
#        [3.3602907 ],
#        [3.45068537],
#        [3.42658013],
#        [3.34823807],
#        [3.26989602],
#        [3.37234332],
#        [3.29400127],
#        [3.50492218],
#        [3.19758028],
#        [3.3120802 ],
#        [3.39644857],
#        [3.36631701],
#        [3.4145275 ],
#        [3.18552765],
#        [3.43863275],
#        [3.39644857],
#        [3.45671169],
#        [3.37234332],
#        [3.30002758],
#        [3.37836963],
#        [3.51094849],
# ...

# %%
COMP=pd.DataFrame(X_test,columns=['ph'])

# %%
COMP
# Out:
#        ph
# 0    10.8
# 1     8.1
# 2     9.1
# 3    10.2
# 4    12.2
# ..    ...
# 315  10.1
# 316   6.9
# 317   9.1
# 318   9.1
# 319   8.2
#
# [320 rows x 1 columns]

# %%
COMP['quality']=Y_test

# %%
COMP
# Out:
#        ph  quality
# 0    10.8     3.17
# 1     8.1     3.36
# 2     9.1     3.26
# 3    10.2     3.17
# 4    12.2     3.13
# ..    ...      ...
# 315  10.1     3.17
# 316   6.9     3.44
# 317   9.1     3.18
# 318   9.1     3.29
# 319   8.2     3.27
#
# [320 rows x 2 columns]

# %%
COMP['PRDDATA']=y_predict

# %%
COMP
# Out:
#        ph  quality   PRDDATA
# 0    10.8     3.17  3.161422
# 1     8.1     3.36  3.324133
# 2     9.1     3.26  3.263870
# 3    10.2     3.17  3.197580
# 4    12.2     3.13  3.077054
# ..    ...      ...       ...
# 315  10.1     3.17  3.203607
# 316   6.9     3.44  3.396449
# 317   9.1     3.18  3.263870
# 318   9.1     3.29  3.263870
# 319   8.2     3.27  3.318107
#
# [320 rows x 3 columns]

# %%
pt.scatter(x,y,color='black')
pt.plot(X_test,y_predict,color='yellow')
pt.xlabel('PH')
pt.ylabel('QUALITY')
pt.title('LINEAR REGRESSION')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(Y_test,y_predict)
# Out:
# 0.012487990349808964

# %%
mean_absolute_error(Y_test,y_predict)
# Out:
# 0.08648977484595083

# %%
r2_score(Y_test,y_predict)
# Out:
# 0.48646736420848036

# %%
lm.score(X_test,Y_test)
# Out:
# 0.48646736420848036
