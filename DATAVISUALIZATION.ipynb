# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
ph=pd.read_csv("C:\\Users\\aedpu\\Downloads\\winequality-red (1).csv")

# %%
ph
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
pH=ph.drop(['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','sulphates','alcohol','quality'],axis=1)

# %%
quality=pd.read_csv("C:\\Users\\aedpu\\Downloads\\winequality-red (1).csv")

# %%
qua=quality.drop(['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol',],axis=1)

# %%
qua
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
pH
# Out:
#         pH
# 0     3.51
# 1     3.20
# 2     3.26
# 3     3.16
# 4     3.51
# ...    ...
# 1594  3.45
# 1595  3.52
# 1596  3.42
# 1597  3.57
# 1598  3.39
#
# [1599 rows x 1 columns]

# %%
plt.scatter(qua,pH,color="red")

# %%
plt.plot(pH,qua,linestyle='dotted',color='red')

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')

# %%
sns.relplot(x='pH',y='quality',data=ph)

# %%
sns.relplot(x='pH',y='quality',data=ph,hue="pH",kind="scatter")
